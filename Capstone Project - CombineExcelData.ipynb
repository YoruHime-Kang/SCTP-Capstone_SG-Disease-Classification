# %%
import pandas as pd
import os

# Directory where all your Excel files are located
excel_dir = 'MOH_Data_Raw'

# Create an empty list to store each DataFrame
dfs = []

# Loop through each file in the directory
for filename in os.listdir(excel_dir):
    if filename.endswith('.xlsx') or filename.endswith('.xls'):  # Check for Excel files
        file_path = os.path.join(excel_dir, filename)
        
        # Load the Excel file
        excel_file = pd.ExcelFile(file_path)
        
        # Loop through each sheet in the Excel file
        for sheet_name in excel_file.sheet_names:
            df = pd.read_excel(file_path, sheet_name=sheet_name, header=1)  # Read from row 2 (index 1)
            dfs.append(df)  # Append the DataFrame to the list

# Concatenate all DataFrames, aligning on columns
combined_df = pd.concat(dfs, ignore_index=True)

combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 57 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Epidemiology Wk                     660 non-null    object
#  1   Start                               660 non-null    object
#  2   End                                 660 non-null    object
#  3   Cholera                             659 non-null    float64
#  4   Paratyphoid                         659 non-null    float64
#  5   Typhoid                             659 non-null    float64
#  6   Acute Viral Hepatitis A             398 non-null    float64
#  7   Acute Viral Hepatitis E             398 non-null    float64
#  8   Poliomyelitis                       657 non-null    float64
#  9   Plague                              658 non-null    float64
#  10  Yellow Fever                        659 non-null    float64
# ...

# %%
combined_df = combined_df.fillna(0)

combined_df.info()

# Save the combined DataFrame to a CSV file
csv_output_path = 'combined_infectious_disease_data.csv'
combined_df.to_csv(csv_output_path, index=False)
